# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %% [markdown]
# # COVID-19

# %%
# Find path to the csv file
covid19_path='../Datasets/Pandemic/COVID-19 Cases.csv'

# %%
# Read in csv and print head of df
covid19_df = pd.read_csv(covid19_path)
covid19_df.head()
# Out:
#    Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0     Deaths      0           0  2/27/2020        Bahamas            NaN
# 1  Confirmed     16           0  2/16/2020        Germany            NaN
# 2     Deaths      0           0  1/31/2020         Canada        Alberta
# 3     Deaths      0           0   3/4/2020      Australia     Queensland
# 4  Confirmed      0           0  1/25/2020       Suriname            NaN
#
#   Admin2 Combined_Key  FIPS      Lat      Long  Table_Names  \
# 0    NaN          NaN   NaN  25.0343  -77.3963  Time Series
# 1    NaN          NaN   NaN  51.0000    9.0000  Time Series
# 2    NaN          NaN   NaN  53.9333 -116.5765  Time Series
# 3    NaN          NaN   NaN -28.0167  153.4000  Time Series
# 4    NaN          NaN   NaN   3.9193  -56.0278  Time Series
#
#      Prep_Flow_Runtime
# 0  4/7/2020 8:34:39 PM
# 1  4/7/2020 8:34:39 PM
# 2  4/7/2020 8:34:39 PM
# 3  4/7/2020 8:34:39 PM
# 4  4/7/2020 8:34:39 PM

# %%
# Select necessary columns and renaming if needed
covid19_df_2 = covid19_df[['Date', 'Case_Type', 'Cases', 'Difference', 'Country_Region',
       'Province_State', 'Admin2']]
covid19_df_2 = covid19_df_2.rename(columns = {'Cases':'Cumulative_Cases','Difference':'Daily_Cases',
                                                              'Country_Region':'Country', 'Province_State':'State',
                                                              'Admin2':'County'}) 
covid19_df_2.head()
# Out:
#         Date  Case_Type  Cumulative_Cases  Daily_Cases    Country       State  \
# 0  2/27/2020     Deaths                 0            0    Bahamas         NaN
# 1  2/16/2020  Confirmed                16            0    Germany         NaN
# 2  1/31/2020     Deaths                 0            0     Canada     Alberta
# 3   3/4/2020     Deaths                 0            0  Australia  Queensland
# 4  1/25/2020  Confirmed                 0            0   Suriname         NaN
#
#   County
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
# Fill in NaN values in columns so they dont dropped when pivoting the df
covid19_df_2 = covid19_df_2.fillna('None')
covid19_df_2.head()
# Out:
#         Date  Case_Type  Cumulative_Cases  Daily_Cases    Country       State  \
# 0  2/27/2020     Deaths                 0            0    Bahamas        None
# 1  2/16/2020  Confirmed                16            0    Germany        None
# 2  1/31/2020     Deaths                 0            0     Canada     Alberta
# 3   3/4/2020     Deaths                 0            0  Australia  Queensland
# 4  1/25/2020  Confirmed                 0            0   Suriname        None
#
#   County
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None

# %%
# Pivot df so Case_Type (Deaths and Confirmed) become columns of their own
covid19_pivoted_df = covid19_df_2.pivot_table(index=['Date', 'Country', 'State', 'County'], 
                        columns='Case_Type', 
                        values='Daily_Cases',
                        aggfunc=sum)
covid19_pivoted_df.head()
# Out:
# Case_Type                           Confirmed  Deaths
# Date      Country     State County
# 1/22/2020 Afghanistan None  None            0       0
#           Albania     None  None            0       0
#           Algeria     None  None            0       0
#           Andorra     None  None            0       0
#           Angola      None  None            0       0

# %%
# Reset index so we dont have grouped columns
covid19_pivoted_df.reset_index(inplace=True)
covid19_pivoted_df.head()
# Out:
# Case_Type       Date      Country State County  Confirmed  Deaths
# 0          1/22/2020  Afghanistan  None   None          0       0
# 1          1/22/2020      Albania  None   None          0       0
# 2          1/22/2020      Algeria  None   None          0       0
# 3          1/22/2020      Andorra  None   None          0       0
# 4          1/22/2020       Angola  None   None          0       0

# %%
# Now we want to get rid of any rows that have zero (0) on noth the Confirmed and Deaths columns, and reset the index
cols_of_interest = ['Confirmed', 'Deaths']
covid19_cleaned_df = covid19_pivoted_df[(covid19_pivoted_df[cols_of_interest] != 0).any(axis=1)]
covid19_cleaned_df = covid19_cleaned_df.reset_index(drop=True)
covid19_cleaned_df.head()
# Out:
# Case_Type       Date Country      State County  Confirmed  Deaths
# 0          1/23/2020   China      Anhui   None          8       0
# 1          1/23/2020   China    Beijing   None          8       0
# 2          1/23/2020   China  Chongqing   None          3       0
# 3          1/23/2020   China     Fujian   None          4       0
# 4          1/23/2020   China      Gansu   None          2       0

# %%
# Save cleaned df into new csv
covid19_cleaned_df.to_csv('../Datasets/Pandemic/COVID19-clean.csv', index=False)
